# %%
from keras.datasets import imdb
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense

# %%
max_features = 20000
maxlen = 80
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_features)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 2s 0us/step

# %%
import keras.utils

# %%
# Preprocess the data
X_train = keras.utils.pad_sequences(X_train, maxlen=maxlen)
X_test = keras.utils.pad_sequences(X_test, maxlen=maxlen)

# %%
# Define the LSTM model
model = Sequential()
model.add(Embedding(max_features, 128, input_length=maxlen))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, batch_size=32, epochs=15, validation_data=(X_test, y_test))
# Out:
# Epoch 1/15
# 782/782 [==============================] - 269s 339ms/step - loss: 0.4396 - accuracy: 0.7932 - val_loss: 0.4161 - val_accuracy: 0.8226
# Epoch 2/15
# 782/782 [==============================] - 269s 344ms/step - loss: 0.2543 - accuracy: 0.8972 - val_loss: 0.3772 - val_accuracy: 0.8400
# Epoch 3/15
# 782/782 [==============================] - 280s 358ms/step - loss: 0.1663 - accuracy: 0.9382 - val_loss: 0.4406 - val_accuracy: 0.8237
# Epoch 4/15
# 782/782 [==============================] - 274s 351ms/step - loss: 0.1173 - accuracy: 0.9576 - val_loss: 0.5623 - val_accuracy: 0.8171
# Epoch 5/15
# 782/782 [==============================] - 270s 345ms/step - loss: 0.0714 - accuracy: 0.9759 - val_loss: 0.7021 - val_accuracy: 0.8180
# Epoch 6/15
# 782/782 [==============================] - 258s 330ms/step - loss: 0.0550 - accuracy: 0.9817 - val_loss: 0.7249 - val_accuracy: 0.8222
# Epoch 7/15
# 782/782 [==============================] - 269s 345ms/step - loss: 0.0380 - accuracy: 0.9878 - val_loss: 0.8090 - val_accuracy: 0.8108
# Epoch 8/15
# 782/782 [==============================] - 269s 345ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.8607 - val_accuracy: 0.8136
# Epoch 9/15
# 782/782 [==============================] - 271s 347ms/step - loss: 0.0257 - accuracy: 0.9918 - val_loss: 0.9212 - val_accuracy: 0.8122
# Epoch 10/15
# 782/782 [==============================] - 269s 344ms/step - loss: 0.0220 - accuracy: 0.9936 - val_loss: 1.0178 - val_accuracy: 0.8075
# Epoch 11/15
# 782/782 [==============================] - 256s 328ms/step - loss: 0.0177 - accuracy: 0.9940 - val_loss: 0.9138 - val_accuracy: 0.8049
# Epoch 12/15
# 782/782 [==============================] - 269s 344ms/step - loss: 0.0120 - accuracy: 0.9959 - val_loss: 0.9600 - val_accuracy: 0.8135
# Epoch 13/15
# 782/782 [==============================] - 268s 343ms/step - loss: 0.0124 - accuracy: 0.9962 - val_loss: 1.0563 - val_accuracy: 0.8150
# Epoch 14/15
# 782/782 [==============================] - 269s 344ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 1.2649 - val_accuracy: 0.8176
# Epoch 15/15
# 782/782 [==============================] - 272s 348ms/step - loss: 0.0103 - accuracy: 0.9972 - val_loss: 1.1243 - val_accuracy: 0.8050

# %%
# Evaluate the model
score, acc = model.evaluate(X_test, y_test, batch_size=32)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# 782/782 [==============================] - 29s 37ms/step - loss: 1.1243 - accuracy: 0.8050
# Test score: 1.1242921352386475
# Test accuracy: 0.8050000071525574

# %%
model.save('my_model1.h5')

# %%
from keras.models import load_model

# %%
# Load the saved model
loaded_model = load_model('my_model1.h5')
